# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/indian-medicine-data/medicine_data.csv

# %%
df= pd.read_csv('/kaggle/input/indian-medicine-data/medicine_data.csv')
df.head()
# Out:
#           sub_category                                       product_name  \
# 0  Human Insulin Basal  Human Insulatard 40IU/ml Suspension for Injection
# 1  Human Insulin Basal                          Insulin 40IU/ml Injection
# 2  Human Insulin Basal                     Huminsulin N 40IU/ml Injection
# 3  Human Insulin Basal                        Insugen-N 40IU/ml Injection
# 4  Human Insulin Basal                        Insulatard 100IU/ml Flexpen
#
#               salt_composition product_price  \
# 0      Insulin Isophane (40IU)       ₹133.93
# 1      Insulin Isophane (40IU)       ₹121.91
# 2      Insulin Isophane (40IU)       ₹133.45
# 3      Insulin Isophane (40IU)       ₹133.36
# 4  Insulin Isophane (100IU/ml)       ₹401.03
#
#                   product_manufactured  \
# 0           Novo Nordisk India Pvt Ltd
# 1    Sun Pharmaceutical Industries Ltd
# 2  Eli Lilly and Company India Pvt Ltd
# 3                               Biocon
# 4           Novo Nordisk India Pvt Ltd
#
#                                        medicine_desc  \
# 0  Human Insulatard 40IU/ml Suspension for Inject...
# 1  Insulin 40IU/ml Injection is used to improve b...
# 2  Huminsulin N 40IU/ml Injection is used to impr...
# 3  Insugen-N 40IU/ml Injection is used to improve...
# 4  Insulatard 100IU/ml Flexpen is used to improve...
#
#                                         side_effects  \
# 0  Hypoglycemia (low blood glucose level),Injecti...
# 1  Hypoglycemia (low blood glucose level),Injecti...
# 2  Hypoglycemia (low blood glucose level),Injecti...
# 3  Hypoglycemia (low blood glucose level),Injecti...
# 4  Hypoglycemia (low blood glucose level),Injecti...
#
#                                    drug_interactions
# 0  {"drug": ["Benazepril", "Captopril", "Enalapri...
# 1  {"drug": ["Benazepril", "Captopril", "Enalapri...
# 2  {"drug": ["Benazepril", "Captopril", "Enalapri...
# 3  {"drug": ["Benazepril", "Captopril", "Enalapri...
# 4  {"drug": ["Benazepril", "Captopril", "Enalapri...

# %%
df.isnull().sum()/len(df)*100
# Out:
# sub_category            0.000000
# product_name            0.000000
# salt_composition        0.000000
# product_price           9.936351
# product_manufactured    0.000000
# medicine_desc           0.000000
# side_effects            0.000000
# drug_interactions       0.000000
# dtype: float64

# %%
df.dropna(subset=['product_price'],inplace= True, ignore_index= True)
df.isnull().sum()/len(df)*100
# Out:
# sub_category            0.0
# product_name            0.0
# salt_composition        0.0
# product_price           0.0
# product_manufactured    0.0
# medicine_desc           0.0
# side_effects            0.0
# drug_interactions       0.0
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print(df.info())
df.describe(include='all').transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176169 entries, 0 to 176168
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   sub_category          176169 non-null  object
#  1   product_name          176169 non-null  object
#  2   salt_composition      176169 non-null  object
#  3   product_price         176169 non-null  object
#  4   product_manufactured  176169 non-null  object
#  5   medicine_desc         176169 non-null  object
#  6   side_effects          176169 non-null  object
#  7   drug_interactions     176169 non-null  object
# dtypes: object(8)
# memory usage: 10.8+ MB
# None
#                        count unique  \
# sub_category          176169    240
# product_name          176169   6043
# salt_composition      176169   2245
# product_price         176169   3782
# product_manufactured  176169    789
# medicine_desc         176169   6043
# side_effects          176169   1035
# drug_interactions     176169    162
#
#                                                                     top  \
# sub_category                                             Cephalosporins
# product_name                                        Taxim 1gm Injection
# salt_composition                           Cefpodoxime Proxetil (200mg)
# product_price                                                    ₹130.9
# product_manufactured                  Sun Pharmaceutical Industries Ltd
# medicine_desc         Taxim 1gm Injection is an antibiotic medicine ...
# side_effects                                   Vomiting,Nausea,Diarrhea
# drug_interactions               {"drug": [], "brand": [], "effect": []}
#
#                         freq
# sub_category           24045
# product_name             619
# salt_composition        4314
# product_price           1300
# product_manufactured   18623
# medicine_desc            619
# side_effects            7585
# drug_interactions     107737

# %%
plt.figure(figsize=(15,12))
df['sub_category'].value_counts(). plot(kind='bar')
plt.show()

# %%
plt.hist(df['product_price'], bins=30, edgecolor='k')
plt.xlabel('product_price')
plt.show()

# %%
# Out:
#   Cell In[10], line 1
#     table= pd.crosstab(df['product_manufactured']
#                                                  ^
# SyntaxError: incomplete input
